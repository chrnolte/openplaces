# %%
from openplaces.diagnostics import find_recipes, map_recipe_coverage

df = find_recipes('building', stage='ingest')

df

# %%
map_recipe_coverage

# %%
fig, ax = map_recipe_coverage('building', stage='ingest', verbose=True)

# %%
df = find_recipes('parcel')
# Expect 6 rows: obm, ghs, fema, microsoft, nsi, ncdps

df

# %%
fig, ax = map_recipe_coverage('parcel', verbose=True)
